# %% [markdown]
# # PART II:
#
# Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.
#
# __Domain:__ Food and agriculture
#
# __Context:__
#
# In 2006, a global concern was raised over the rapid decline in the honeybee population, an integral component
# to American honey agriculture. Large numbers of hives were lost to “Colony-Collapse-Disorder”, a
# phenomenon of disappearing “worker-bees” causing the remaining “hive-colony” to collapse. Speculation
# around the cause of this disorder points to hive-diseases and pesticides harming the pollinators, though no
# overall consensus has been reached. Twelve years later, some industries are observing recovery but the
# American honey industry is still largely struggling. The U.S. used to locally produce over half the honey it
# consumes per year. Now, honey mostly comes from overseas, with 350 of the 400 million pounds of honey
# consumed every year originating from imports. This dataset provides insight into honey production supply and
# demand in America by state from 1998 to 2012.
#
# __Objective:__
#
# The Goal is to use Python visualization libraries such as seaborn and matplotlib to investigate the data and get
# some useful conclusions.
#
# __Attribute Information :__
# 1. __numcol :__ Number of honey producing colonies.
# 2. __yield :__ percol Honey yield per colony. (Unit is pounds)
# 3. __total prod :__ Total production (numcol x yieldpercol). (Unit is pounds)
# 4. __price per lb :__ Refers to average price per pound based on expanded sales. Unit is dollars.
# 5. __prodvalue :__ Value of production (total prod x priceperlb). Unit is dollars.
# 6. __Stocks :__ Refers to stocks held by producers. Unit is pounds
# 7. __Year :__ Calendar year.
# 8. __State :__ Different states' names.

# %% [markdown]
# # Questions:-
# <h3>1. Import required libraries and read the dataset.<h3>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings as warnings
warnings.filterwarnings("ignore")

df=pd.read_csv('honeyproduction1998-2016.csv')

# %% [markdown]
# ### 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()
# Out:
#         state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1     Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2    Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3  California  450000.0           83  37350000.0  12326000.0        0.62
# 4    Colorado   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.sample(5)
# Out:
#           state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 468    Arkansas   24000.0           57   1368000.0    301000.0        1.42
# 398   Louisiana   29000.0           89   2581000.0    413000.0        1.08
# 89   California  440000.0           70  30800000.0  11396000.0        0.59
# 642    Michigan   85000.0           55   4675000.0    982000.0        2.16
# 101       Maine   11000.0           21    231000.0    143000.0        0.75
#
#       prodvalue  year
# 468   1943000.0  2009
# 398   2787000.0  2007
# 89   18172000.0  2000
# 642  10098000.0  2013
# 101    173000.0  2000

# %%
df.shape   #785-rows , 8-columns
# Out:
# (785, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785 entries, 0 to 784
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        785 non-null    object
#  1   numcol       785 non-null    float64
#  2   yieldpercol  785 non-null    int64
#  3   totalprod    785 non-null    float64
#  4   stocks       785 non-null    float64
#  5   priceperlb   785 non-null    float64
#  6   prodvalue    785 non-null    float64
#  7   year         785 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 49.2+ KB

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     785.000000   785.000000  7.850000e+02  7.850000e+02  785.000000
# mean    61686.624204    60.578344  4.140957e+06  1.257629e+06    1.695159
# std     92748.940458    19.427831  6.884594e+06  2.211794e+06    0.930623
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    46.000000  4.700000e+05  1.190000e+05    1.050000
# 50%     26000.000000    58.000000  1.500000e+06  3.910000e+05    1.480000
# 75%     65000.000000    72.000000  4.096000e+06  1.380000e+06    2.040000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    7.090000
#
#           prodvalue         year
# count  7.850000e+02   785.000000
# mean   5.489739e+06  2006.817834
# std    9.425394e+06     5.491523
# min    1.620000e+05  1998.000000
# 25%    9.010000e+05  2002.000000
# 50%    2.112000e+06  2007.000000
# 75%    5.559000e+06  2012.000000
# ...

# %%
df.describe(include='object')
# Out:
#           state
# count       785
# unique       44
# top     Alabama
# freq         19

# %% [markdown]
# ### 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
plt.figure(figsize=(15,6))
df['year'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='year'>

# %% [markdown]
# ### 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data=df,x='priceperlb',kde=True)

# %% [markdown]
# - __On visualizing the distribution using a displot, we see that the  distribution of average price per pound is right skewed, indicating that data distribution is trailing off to the right, and the majority of price per pound are present on the lower end of the scale.__
# - __The Mean price per pound  is greater than its Median.__
# - __Trailing off to the right will effect mean of the distribution.Mean of "price per lb" could be influenced by the higher data values that is present on right side.__

# %% [markdown]
# ### 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(data=df,x='numcol',y='prodvalue')
# Out:
# <Axes: xlabel='numcol', ylabel='prodvalue'>

# %% [markdown]
# - __Positive linear relationship exists between the variables 'numcol' and 'prodval'.__
# - __We can say that as the Number of honey producing colonies  increases  the  Production Value also increases.__
# - __We can say that this provides a hope for the recovery of the  American honey agriculture.__

# %% [markdown]
# ### 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='year',y='prodvalue')
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %% [markdown]
# - __The boxplot indicates the presence of outliers in the upper whisker which suggests that there might be extreme values in the 'prodvalue' for certain years.__
# - __The medians for 'prodvalue' across all the years are in the range of 0 to 0.5.__
# - __We can see that the there is slight variation in IQR across all years indicating variation in annual total production.__

# %% [markdown]
# ### 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
plt.figure(figsize=(15,6))
sns.pairplot(df,vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue'],hue='year',palette='plasma')

# %% [markdown]
# - __The num_col,totalprod,prodvalue is slightly right skewed across all the years.__
# - __The yielpercol is somewhat normally distributed across the years 1999-2005.__
# - __Positive linear relationship exists between the variables 'numcol' and 'prodval',indicating higher the the number of colonies higher the production value.__
# - __Positive linear relationship exists between the variables 'numcol' and 'totalprod',indicating higher the the number of colonies greater the total production.__
# - __Positive linear relationship exists between the variables 'totalprod' and 'prodvalue',indicating higher the total production greater is the value of production.__

# %% [markdown]
# ### 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
corr=df.corr()
sns.heatmap(data=corr,annot=True,cmap='PuBu')
# Out:
# <Axes: >

# %% [markdown]
# __Positive Correlation__
# - We can see that 'totalprod' & 'numcol' has correlation coefficient of 0.95 indicating a very strong positive linear relationship between these two variables.It suggests that as number of colonies increases  total honey production also increases.
# - Followed by which we can also see that 'numcol' & 'prodvalue'  and  also 'totalprod' & 'prodvalue' has correlation coefficient of 0.9 indicating a very strong positive linear relationship between each of them.
# - Here 'prodvalue' & 'year' have correlation coefficient of 0.19 indicating weak positive linear relationship
#
# __Negative Correlation__
#
# - Correlation coefficient of -0.36 indicates a somewhat negative linear relationship between 'yieldpercol' &'priceperlb',meaning as Honey yield per colony increases average price per pound decreases or vice versa.
# - Correlation coefficient of -0.28 indicates a somewhat negative linear relationship between 'stocks' and 'priceperlb',meaning as stock units increases average price per pound decreases or vice versa.
# - Correlation coefficient of -0.04 between 'totalprod' and 'year' indicates a very weak negative correlation.
